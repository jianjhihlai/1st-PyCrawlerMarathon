# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        meta_tags = r.find_all(class_='article-meta-tag')
        meta_vals = r.find_all(class_='article-meta-value')
        for tag, val in zip(meta_tags, meta_vals):
            if tag.text == '作者':
                print('作者: ' + val.text)
            if tag.text == '時間':
                print('時間: ' + val.text)
    except:
        continue
# Out:
# (本文已被刪除) [namie810303]
# [問卷]現今NBA季後賽制度滿意度調查
# 作者: ray562380 (bmsforever)
# 時間: Sun Jan  5 14:15:29 2020
# [討論] 2010s最強控球後衛
# 作者: la1aco (lalaco)
# 時間: Sun Jan  5 14:32:57 2020
# [新聞] 打法難宰制當今聯盟? 俠客:我會是字母哥
# 作者: currykukuo (陳菊濕汗)
# 時間: Sun Jan  5 14:57:06 2020
# [新聞] 過多的肢體碰撞讓唐西奇吃不消？
# 作者: go190214 (天空之島拉普達)
# 時間: Sun Jan  5 15:09:49 2020
# Re: [情報] 騎士總教練談Love比賽中發脾氣：我的錯
# 作者: azlbf (上邪!我欲與君相知)
# 時間: Sun Jan  5 15:31:28 2020
# Re: [花邊] 某NBA球迷挑戰30天登上30座球場大螢幕
# 作者: nogoodlaugh (KG is back!!)
# 時間: Sun Jan  5 15:51:51 2020
# [公告] 水桶
# 作者: dragon803 (好想去露營啊~)
# 時間: Sun Jan  5 16:30:18 2020
# [公告] 板規v6.8
# [公告] 樂透取消及未來不再開啟樂透
# 作者: Vedan (味丹)
# 時間: Mon Jun 24 15:08:02 2019
# [公告] 版主上任相關事項
# 作者: qazwsx879345 (Rajon Rondo)
# 時間: Fri Oct 25 10:44:03 2019
# [情報] SEASON Schedule 賽程 January 19–20
# 作者: Acetoxy (阿斯)
# 時間: Fri Jan  3 01:37:35 2020

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
url = 'https://www.ptt.cc/bbs/NBA/index1.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        meta_tags = r.find_all(class_='article-meta-tag')
        meta_vals = r.find_all(class_='article-meta-value')
        for tag, val in zip(meta_tags, meta_vals):
            if tag.text == '作者':
                print('作者: ' + val.text)
            if tag.text == '時間':
                print('時間: ' + val.text)
    except:
        continue
# Out:
# [轉錄]Lyotard 對於太陽板討論串的結論
# 作者: Price (Price)
# 時間: Sun May 16 01:54:33 2004
# [公告] 請停止一切關於本次活動的發言
# 作者: Price (Price)
# 時間: Mon May 24 00:43:00 2004
# [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 作者: Frankaze (神采風華)
# 時間: Tue Jun  8 01:16:45 2004
# [轉錄]再轉一篇好文來
# 作者: Frankaze (神采風華)
# 時間: Tue Jun  8 09:02:23 2004
# [轉錄][情報] 夏洛特山貓系列
# 作者: Price (Price)
# 時間: Thu Jun 10 00:39:35 2004
# [轉錄]Re: [心得] 真是受不了糗爺....
# 作者: Price (Price)
# 時間: Thu Jun 10 00:51:35 2004
# [轉錄]總冠軍賽NO.2觀後感
# 作者: Price (Price)
# 時間: Thu Jun 10 12:05:07 2004
# [心得] Rasheed Wallace
# 作者: AmuroNamie (原來太嗨真的會失眠^___^)
# 時間: Fri Jun 11 15:06:09 2004
# 掌控球賽的男人
# 作者: toptree (  )
# 時間: Sat Jun 12 07:13:04 2004
# [閒聊] 說說2004季後賽名場面回顧
# 作者: skchang (3EB板開板囉！)
# 時間: Sat Jun 12 13:21:49 2004
# [心得] 其實說穿了 就是活塞的防守太可怕了
# 作者: shineup ()
# 時間: Sat Jun 12 13:12:47 2004
# Re: [閒聊] 說說2004季後賽名場面回顧
# 作者: cOvi (喵~)
# 時間: Sat Jun 12 16:43:07 2004
# Re: [閒聊] 說說2004季後賽名場面回顧
# 作者: ykshih (￼N￼Ns)
# 時間: Sat Jun 12 17:26:37 2004
# Re: [閒聊] 說說2004季後賽名場面回顧
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
url = 'https://www.ptt.cc/bbs/Tech_Job/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

for d in soup.find_all(class_="title"):
    print(d.text.replace('\t', '').replace('\n', ''))
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        meta_tags = r.find_all(class_='article-meta-tag')
        meta_vals = r.find_all(class_='article-meta-value')
        for tag, val in zip(meta_tags, meta_vals):
            if tag.text == '作者':
                print('作者: ' + val.text)
            if tag.text == '時間':
                print('時間: ' + val.text)
    except:
        continue
# Out:
# [新聞] 紅色供應鏈奪蘋單 衝擊台廠
# 作者: orz44444 (陰人不應該向陽人裝熟~~)
# 時間: Sat Jan  4 14:35:10 2020
# [問卷]多重職業持有者工作意圖調查
# 作者: Tesarus (牙齒痛)
# 時間: Sat Jan  4 15:18:35 2020
# Re: [請益] 欣興-設備自動化 面試問題
# 作者: n4939733 (monster)
# 時間: Sat Jan  4 17:18:36 2020
# (本文已被刪除) [accprote]
# [徵才] 阿里巴巴徵韌體專家/高級硬體專家(代po)
# 作者: lqke (我思故我在)
# 時間: Sat Jan  4 17:56:58 2020
# Re: [新聞] 紅色供應鏈奪蘋單 衝擊台廠
# 作者: mzt (YOLO)
# 時間: Sat Jan  4 18:10:44 2020
# Re: [討論] 台積底薪為什麼不能跟豬屎屋看齊?
# 作者: pipi1983 (放手￼ ￼ ￼N)
# 時間: Sat Jan  4 21:13:40 2020
# [新聞] 廣明光電判賠惠普金額增為三倍
# 作者: modhairs ( 對錢的渴望)
# 時間: Sat Jan  4 21:59:19 2020
# [新聞] 近7萬元折疊機夯 台灣三星追加訂單
# 作者: hvariables (Speculative Male)
# 時間: Sat Jan  4 22:07:53 2020
# [請益] 敦泰V.S. 鋐寶 【公司請益】
# 作者: Marco456 (Marco)
# 時間: Sat Jan  4 23:25:21 2020
# [請益] 海歸EEE碩士 職涯請益
# 作者: a0955837230 (魚子醬~*)
# 時間: Sun Jan  5 11:07:26 2020
# [請益] 年薪跟月薪的選擇
# 作者: yorickwu (坑爹人生)
# 時間: Sun Jan  5 11:26:32 2020
# [討論] 真會有人會照搬企管mba的東西嗎?
# 作者: hass231470 (hello)
# 時間: Sun Jan  5 13:26:10 2020
# [新聞] 廣明判賠惠普 公司聲明全文來了
# ...
