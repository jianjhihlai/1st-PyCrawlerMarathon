# %% [markdown]
# # HTTP 靜態網頁架構說明
#
# * 認識靜態網頁的溝通架構與運作原理
# * HTML、CSS、JavaScript 在網頁中扮演的角色
# * 網頁中定位資料的方法

# %% [markdown]
# ## 作業目標
#
# 1. （簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？
# 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。

# %% [markdown]
# ### 1.（簡答題）請問目前提到的這種基於 HTTP 一來一回的網頁傳輸方式，有哪些缺點及問題？

# %%
'''
1. 速度比較慢，每次要取資料都要花網路頻寬。
2. 若網站掛掉了，資料就無法取得。
3. HTTP比較沒有安全性，若是開放資料的傳輸比較沒問題，但公司資料就不太合適。
'''
# Out:
# '\n1. 速度比較慢，每次要取資料都要花網路頻寬。\n2. 若網站掛掉了，資料就無法取得。\n3. HTTP比較沒有安全性，若是開放資料的傳輸比較沒問題，但公司資料就不太合適。\n'

# %% [markdown]
# ### 2. （簡答題）網頁中使用的 JavaScipt 程式語言，跟我們一般使用的 Python 在執行上有什麼不同。

# %%
'''
1. 網頁上的JavaScript語言透過瀏覽器執行，Python要裝執行環境。
2. 在網頁上的JavaScript在前端執行 (Client端)，Python在後端執行 (Server端)
'''
# Out:
# '\n1. 網頁上的JavaScript語言透過瀏覽器執行，Python要裝執行環境。\n2. 在網頁上的JavaScript在前端執行 (Client端)，Python在後端執行 (Server端)\n'
